# %%
import json
import pandas as pd
from prophet import Prophet
from prophet.serialize import model_to_json, model_from_json
from prophet.plot import plot_plotly, plot_components_plotly, add_changepoints_to_plot
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error, mean_absolute_error
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import year
from pyspark.sql.functions import to_date
from pyspark.sql import SparkSession	
from pyspark.sql.functions import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# </div>

# %%
OSFcast=spark.read.parquet('/mnt/MLPipeline/Fcast/')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# </div>

# %%
#Convert to Pandas
pdf=OSFcast.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# </div>

# %%
pdf.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>TimePeriod</th>
#       <th>SeatsAvailable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2013-10</td>
#       <td>148</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2013-10</td>
#       <td>86</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2013-10</td>
#       <td>104</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2013-10</td>
#       <td>85</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2013-10</td>
#       <td>13</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# </div>

# %%
 #feature engineering
pdf['TimePeriod'] = pd.to_datetime(pdf['TimePeriod'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# </div>

# %%
#Selecet columns that matters
dfa=pdf[['TimePeriod','SeatsAvailable']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# </div>

# %%
#Prophet feature engineering
dfa= dfa.rename(columns={'TimePeriod': 'ds','SeatsAvailable': 'y'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# </div>

# %%
dfa
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[39]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ds</th>
#       <th>y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2013-10-01</td>
#       <td>148</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2013-10-01</td>
#       <td>86</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2013-10-01</td>
#       <td>104</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2013-10-01</td>
#       <td>85</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2013-10-01</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>964308</th>
#       <td>2016-06-01</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>964309</th>
#       <td>2020-06-01</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>964310</th>
#       <td>2015-11-01</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>964311</th>
#       <td>2018-03-01</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>964312</th>
#       <td>2015-12-01</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>964313 rows × 2 columns</p>
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# </div>

# %%
dfa=dfa.groupby(['ds'],as_index=False)['y'].sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# </div>

# %%
dfa
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[41]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ds</th>
#       <th>y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2013-01-01</td>
#       <td>1626</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2013-02-01</td>
#       <td>2135</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2013-03-01</td>
#       <td>2137</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2013-04-01</td>
#       <td>2137</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2013-05-01</td>
#       <td>360295</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>103</th>
#       <td>2021-08-01</td>
#       <td>308984</td>
#     </tr>
#     <tr>
#       <th>104</th>
#       <td>2021-09-01</td>
#       <td>308984</td>
#     </tr>
#     <tr>
#       <th>105</th>
#       <td>2021-10-01</td>
#       <td>308984</td>
#     </tr>
#     <tr>
#       <th>106</th>
#       <td>2021-11-01</td>
#       <td>308984</td>
#     </tr>
#     <tr>
#       <th>107</th>
#       <td>2021-12-01</td>
#       <td>277552</td>
#     </tr>
#   </tbody>
# </table>
# <p>108 rows × 2 columns</p>
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# </div>

# %%
# x=dfa.groupby(['ds']).size().reset_index(name='count')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#You cant forecast where a category has less than 2 rows so filter them out
# y=x[x['count'] <2]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# y
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# fil_os = y.OSName.unique()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# fil_os
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# os=['Primary','Control','Duty']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# df2=dfa[~dfa['OSName'].isin(fil_os)]
# df2=df2[df2['OSName'].isin(os)]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df2=dfa.copy()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# </div>

# %%
#Prophet Model training in loop. It also saves all forecast results



fcsta_all = pd.DataFrame()
plots_a={}
components_a={}

    
ma = Prophet(changepoint_prior_scale=0.09)
months = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
for i, month in enumerate(months):
    df2[month] = (df2['ds'].dt.month == i + 1).values.astype('float')
    ma.add_regressor(month)

ma.fit(df2 )
future_a= ma.make_future_dataframe(periods=365)
months = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
for i, month in enumerate(months):
       future_a[month] = (future_a['ds'].dt.month == i + 1).values.astype('float')

forecast_a= ma.predict(future_a)
fcsta_all = pd.concat([fcsta_all, forecast_a], ignore_index=True)
fig=plot_plotly(ma, forecast_a)
fig1=plot_components_plotly(ma,forecast_a)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# </div>

# %%
fig.update_layout(showlegend=True,title='Trend and Forecast of Seats Availability',autosize=False,
width=1700,
height=600,template='seaborn')
labels_to_show_in_legend = ["Predicted", "Actual"]

for trace in fig['data']: 
    if (not trace['name'] in labels_to_show_in_legend):
        trace['showlegend'] = False

fig.show()

fig1.update_layout(title='Trend and Forecast of Seats Availability',autosize=False,
width=1700,
height=800,template ='plotly_dark')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c49db644-9166-4cbf-9edc-2a38a08571e3" class="plotly-graph-div" style="height:600px; width:1700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c49db644-9166-4cbf-9edc-2a38a08571e3")) {                    Plotly.newPlot(                        "c49db644-9166-4cbf-9edc-2a38a08571e3",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"Actual","x":["2013-01-01T00:00:00","2013-02-01T00:00:00","2013-03-01T00:00:00","2013-04-01T00:00:00","2013-05-01T00:00:00","2013-06-01T00:00:00","2013-07-01T00:00:00","2013-08-01T00:00:00","2013-09-01T00:00:00","2013-10-01T00:00:00","2013-11-01T00:00:00","2013-12-01T00:00:00","2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","2014-04-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00:00:00","2014-12-01T00:00:00","2015-01-01T00:00:00","2015-02-01T00:00:00","2015-03-01T00:00:00","2015-04-01T00:00:00","2015-05-01T00:00:00","2015-06-01T00:00:00","2015-07-01T00:00:00","2015-08-01T00:00:00","2015-09-01T00:00:00","2015-10-01T00:00:00","2015-11-01T00:00:00","2015-12-01T00:00:00","2016-01-01T00:00:00","2016-02-01T00:00:00","2016-03-01T00:00:00","2016-04-01T00:00:00","2016-05-01T00:00:00","2016-06-01T00:00:00","2016-07-01T00:00:00","2016-08-01T00:00:00","2016-09-01T00:00:00","2016-10-01T00:00:00","2016-11-01T00:00:00","2016-12-01T00:00:00","2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00"],"y":[1626,2135,2137,2137,360295,360295,360295,360432,360432,360313,360313,360313,360313,360313,360313,360313,360313,579062,579413,579413,579413,579413,579413,579413,579413,579145,564206,553724,553724,553724,553706,553706,553706,553706,553706,553701,553701,553701,553701,553701,553701,553701,554531,554531,554531,554531,554531,554531,415923,415923,415923,415923,415923,415923,415923,564434,564434,564434,547326,547326,547326,547326,547325,547328,547328,547328,547328,547328,547328,547328,557413,557413,557413,557413,557413,557413,576632,576632,576632,576632,576632,576632,576632,576632,576632,576632,576632,576632,576632,576632,576632,576632,576632,576632,576632,576632,576632,308984,308984,308984,308984,308984,308984,308984,308984,308984,308984,277552],"type":"scatter"},{"hoverinfo":"skip","line":{"width":0},"mode":"lines","x":["2013-01-01T00:00:00","2013-02-01T00:00:00","2013-03-01T00:00:00","2013-04-01T00:00:00","2013-05-01T00:00:00","2013-06-01T00:00:00","2013-07-01T00:00:00","2013-08-01T00 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8e55c04b-a618-44fc-a78c-b711ba07d92b" class="plotly-graph-div" style="height:800px; width:1700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e55c04b-a618-44fc-a78c-b711ba07d92b")) {                    Plotly.newPlot(                        "8e55c04b-a618-44fc-a78c-b711ba07d92b",                        [{"line":{"color":"#0072B2","width":2},"mode":"lines","name":"trend","x":["2013-01-01T00:00:00","2013-02-01T00:00:00","2013-03-01T00:00:00","2013-04-01T00:00:00","2013-05-01T00:00:00","2013-06-01T00:00:00","2013-07-01T00:00:00","2013-08-01T00:00:00","2013-09-01T00:00:00","2013-10-01T00:00:00","2013-11-01T00:00:00","2013-12-01T00:00:00","2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","2014-04-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00:00:00","2014-12-01T00:00:00","2015-01-01T00:00:00","2015-02-01T00:00:00","2015-03-01T00:00:00","2015-04-01T00:00:00","2015-05-01T00:00:00","2015-06-01T00:00:00","2015-07-01T00:00:00","2015-08-01T00:00:00","2015-09-01T00:00:00","2015-10-01T00:00:00","2015-11-01T00:00:00","2015-12-01T00:00:00","2016-01-01T00:00:00","2016-02-01T00:00:00","2016-03-01T00:00:00","2016-04-01T00:00:00","2016-05-01T00:00:00","2016-06-01T00:00:00","2016-07-01T00:00:00","2016-08-01T00:00:00","2016-09-01T00:00:00","2016-10-01T00:00:00","2016-11-01T00:00:00","2016-12-01T00:00:00","2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2021-12-02T00:00:00","2021-12-03T00:00:00","2021-12-04T00:00:00","2021-12-05T00:00:00","2021-12-06T00:00:00","2021-12-07T00:00:00","2021-12-08T00:00:00","2021-12-09T00:00:00","2021-12-10T00:00:00","2021-12-11T00:00:00","2021-12-12T00:00:00","2021-12-13T00:00:00","2021-12-14T00:00:00","2021-12-15T00:00:00","2021-12-16T00:00:00","2021-12-17T00:00:00","2021-12-18T00:00:00","2021-12-19T00:00:00","2021-12-20T00:00:00","2021-12-21T00:00:00","2021-12-22T00:00:00","2021-12-23T00:00:00","2021-12-24T00:00:00","2021-12-25T00:00:00","2021-12-26T00:00:00","2021-12-27T00:00:00","2021-12-28T00:00:00","2021-12-29T00:00:00","2021-12-30T00:00:00","2021-12-31T00:00:00","2022-01-01T00:00:00","2022-01-02T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-08T00:00:00","2022-01-09T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-15T00:00:00","2022-01-16T ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# </div>

# %%
import plotly.graph_objs as go
fig=go.Figure()



    
dff= fcsta_all.copy()
dfy= df2.copy()

fig.add_trace(go.Scatter(
name = 'predicted trend',
mode = 'lines',
x = list(dff['ds']),
y = list(dff['yhat']),
marker=dict(
    color='red',
    line=dict(width=3))))

fig.add_trace(go.Scatter(
name = 'upper band',
mode = 'lines',
x = list(dff['ds']),
y = list(dff['yhat_upper']),
line= dict(color='#57b88f'),
fill = 'tonexty'))

fig.add_trace(go.Scatter(
name= 'lower band',
mode = 'lines',
x = list(dff['ds']),
y = list(dff['yhat_lower']),
line= dict(color='#1705ff')))

fig.add_trace(go.Scatter(
name = 'Actual',
mode = 'markers',
x = list(dfy['ds']),
y = list(dfy['y']),
marker=dict(
  color='pink',
  line=dict(width=2))))


    

fig.update_layout(title='Trend and Forecast of Seats Availability',showlegend=True,template='plotly_dark')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4f32dc9d-8dd9-4de0-9120-ee5b845b102c" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f32dc9d-8dd9-4de0-9120-ee5b845b102c")) {                    Plotly.newPlot(                        "4f32dc9d-8dd9-4de0-9120-ee5b845b102c",                        [{"marker":{"color":"red","line":{"width":3}},"mode":"lines","name":"predicted trend","x":["2013-01-01T00:00:00","2013-02-01T00:00:00","2013-03-01T00:00:00","2013-04-01T00:00:00","2013-05-01T00:00:00","2013-06-01T00:00:00","2013-07-01T00:00:00","2013-08-01T00:00:00","2013-09-01T00:00:00","2013-10-01T00:00:00","2013-11-01T00:00:00","2013-12-01T00:00:00","2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","2014-04-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00:00:00","2014-12-01T00:00:00","2015-01-01T00:00:00","2015-02-01T00:00:00","2015-03-01T00:00:00","2015-04-01T00:00:00","2015-05-01T00:00:00","2015-06-01T00:00:00","2015-07-01T00:00:00","2015-08-01T00:00:00","2015-09-01T00:00:00","2015-10-01T00:00:00","2015-11-01T00:00:00","2015-12-01T00:00:00","2016-01-01T00:00:00","2016-02-01T00:00:00","2016-03-01T00:00:00","2016-04-01T00:00:00","2016-05-01T00:00:00","2016-06-01T00:00:00","2016-07-01T00:00:00","2016-08-01T00:00:00","2016-09-01T00:00:00","2016-10-01T00:00:00","2016-11-01T00:00:00","2016-12-01T00:00:00","2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2021-12-02T00:00:00","2021-12-03T00:00:00","2021-12-04T00:00:00","2021-12-05T00:00:00","2021-12-06T00:00:00","2021-12-07T00:00:00","2021-12-08T00:00:00","2021-12-09T00:00:00","2021-12-10T00:00:00","2021-12-11T00:00:00","2021-12-12T00:00:00","2021-12-13T00:00:00","2021-12-14T00:00:00","2021-12-15T00:00:00","2021-12-16T00:00:00","2021-12-17T00:00:00","2021-12-18T00:00:00","2021-12-19T00:00:00","2021-12-20T00:00:00","2021-12-21T00:00:00","2021-12-22T00:00:00","2021-12-23T00:00:00","2021-12-24T00:00:00","2021-12-25T00:00:00","2021-12-26T00:00:00","2021-12-27T00:00:00","2021-12-28T00:00:00","2021-12-29T00:00:00","2021-12-30T00:00:00","2021-12-31T00:00:00","2022-01-01T00:00:00","2022-01-02T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-08T00:00:00","2022-01-09T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-15T00:00:00 ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# </div>
